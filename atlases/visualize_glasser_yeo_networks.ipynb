# %% [markdown]
# # Glasser atlas Yeo-network viewer (ipyniivue)
#
# This notebook visualizes the Glasser atlas segmentation volume and provides a dropdown to filter by **Yeo community network** (`community_yeo` in `atlas-Glasser_dseg.tsv`).
#
# Use the widget controls to toggle the background / mask, adjust mask opacity, and (optionally) smooth the rendering.

# %%
from pathlib import Path
import sys

# Import the visualization helper from this repo
ATLASES_DIR = Path('__PROJECT_ROOT__/code/atlases')
sys.path.append(str(ATLASES_DIR))

from visualize_glasser_yeo_networks_ipyniivue import display_glasser_yeo_networks

display_glasser_yeo_networks(initial_yeo='All')
